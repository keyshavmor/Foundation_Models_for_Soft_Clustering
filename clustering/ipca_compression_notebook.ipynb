# %% [markdown]
# ## Imports & parameters

# %%
import scanpy as sc
import pandas as pd
import numpy as np
from sklearn.decomposition import IncrementalPCA
import pathlib
from tqdm.notebook import tqdm

DATA_PATH = pathlib.Path('./raw_embeddings/SN(Train)_to_Combined(Test)_3000_Genes_CellState_X_scGPT.h5ad')
OUTPUT_DIR = './resources/embeddings/'
EMBED_KEY = 'X_scGPT'

# %% [markdown]
# ## Load dataset

# %%
if not DATA_PATH.is_file():
    raise FileNotFoundError(f"Data file not found: {DATA_PATH}")
adata = sc.read_h5ad(DATA_PATH)
print(adata)
print('Embedding present:', EMBED_KEY in adata.obsm_keys())
# Out:
# AnnData object with n_obs × n_vars = 258534 × 2969
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'percent_mito', 'Study', 'Assay', 'Platform', 'Sample', 'Patient_No', 'Timepoint', 'INSS_stage', 'MYCN_amplification', 'Gender', 'Risk', 'Cell_condition', 'Cell_type', 'cell', 'n_genes', 'leiden', 'cnv_leiden', 'cnv_score', 'cnv_status', 'Stage_Code', 'Tissue', 'Risk_Category', 'First_Avail_TP', 'MYCN_Status', 'ALK_Status', 'TP53_Status', 'Response', 'Vital_Status', 'Age_at_IDX_in_months', 'Treatment', 'First_Avail_Time_Point', 'sample_name', 'biospecimen_id', 'percent.mt', 'seurat_clusters', 'sample_label_wo_prefix', 'S.Score', 'G2M.Score', 'Phase', 'malignancy', 'cell_state', 'RNA_snn_res.0.2', 'MES_Score', 'ADRN_Score', 'MES_ADRN_diff', 'Event', 'organism_ontology_term_id', 'donor_id', 'development_stage_ontology_term_id', 'sex_ontology_term_id', 'disease_ontology_term_id', 'tissue_type', 'cell_type_ontology_term_id', 'assay_ontology_term_id', 'suspension_type', 'tissue_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'is_primary_data', 'cell_type', 'assay', 'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid', 'cell_type_joint', 'SAMPLES_JOINT'
#     var: 'ensembl_id_mapped', 'gene_name', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'id_in_vocab'
#     uns: 'SAMPLES_JOINT_colors', 'cell_state_colors', 'hvg', 'log1p', 'neighbors', 'umap'
#     obsm: 'X_pca', 'X_scGPT', 'X_umap'
#     layers: 'log1p_norm', 'raw_counts'
#     obsp: 'connectivities', 'distances'
# Embedding present: True

# %% [markdown]
# ## iPCA

# %%
EPOCH = 5
BATCH_SIZE = 5000
N_IPCA = 50
embeddings = adata.obsm[EMBED_KEY].copy()
n_samples, n_features = embeddings.shape

# Create IncrementalPCA object
ipca = IncrementalPCA(n_components=N_IPCA, batch_size=BATCH_SIZE)

# Fit in batches
for e in range(EPOCH):
    print(f'===== EPOCH: {e} =====')
    for batch in tqdm(np.array_split(embeddings, n_samples // BATCH_SIZE)):
        ipca.partial_fit(batch)
# Out:
# ===== EPOCH: 0 =====
#   0%|          | 0/41 [00:00<?, ?it/s]
# ===== EPOCH: 1 =====
#   0%|          | 0/41 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 14
#      12 print(f'===== EPOCH: {e} =====')
#      13 for batch in tqdm(np.array_split(embeddings, n_samples // BATCH_SIZE)):
# ---> 14     ipca.partial_fit(batch)
#
# File /opt/anaconda3/envs/cancerGPT/lib/python3.10/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File /opt/anaconda3/envs/cancerGPT/lib/python3.10/site-packages/sklearn/decomposition/_incremental_pca.py:362, in IncrementalPCA.partial_fit(self, X, y, check_input)
#     351     mean_correction = np.sqrt(
#     352         (self.n_samples_seen_ / n_total_samples) * n_samples
#     353     ) * (self.mean_ - col_batch_mean)
#     354     X = np.vstack(
#     355         (
#     356             self.singular_values_.reshape((-1, 1)) * self.components_,
#    (...)
#     359         )
#     360     )
# --> 362 U, S, Vt = linalg.svd(X, full_matrices=False, check_finite=False)
#     363 U, Vt = svd_flip(U, Vt, u_based_decision=False)
#     364 explained_variance = S**2 / (n_total_samples - 1)
#
# File /opt/anaconda3/envs/cancerGPT/lib/python3.10/site-packages/scipy/linalg/_decomp_svd.py:141, in svd(a, full_matrices, compute_uv, overwrite_a, check_finite, lapack_driver)
#     137 lwork = _compute_lwork(gesXd_lwork, a1.shape[0], a1.shape[1],
#     138                        compute_uv=compute_uv, full_matrices=full_matrices)
#     140 # perform decomposition
# --> 141 u, s, v, info = gesXd(a1, compute_uv=compute_uv, lwork=lwork,
#     142                       full_matrices=full_matrices, overwrite_a=overwrite_a)
#     144 if info > 0:
#     145     raise LinAlgError("SVD did not converge")
#
# KeyboardInterrupt:

# %%
# Transform the data
reduced_embeddings = ipca.transform(embeddings)
print(reduced_embeddings.shape)
# Out:
# (205153, 50)

# %%
iPCA_KEY = 'iPCA_scGPT'
adata.obsm[iPCA_KEY] = reduced_embeddings
adata
# Out:
# /var/folders/ls/z652hgh50nb0drtj7trpjg0h0000gn/T/ipykernel_8657/4249851862.py:2: ImplicitModificationWarning: Setting element `.obsm['iPCA_scFoundation']` of view, initializing view as actual.
#   adata.obsm[iPCA_KEY] = reduced_embeddings
# AnnData object with n_obs × n_vars = 205153 × 18636
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'percent_mito', 'Study', 'Assay', 'Platform', 'Sample', 'Patient_No', 'Timepoint', 'INSS_stage', 'MYCN_amplification', 'Gender', 'Risk', 'Cell_condition', 'Cell_type', 'cell', 'n_genes', 'leiden', 'cnv_leiden', 'cnv_score', 'cnv_status', 'Stage_Code', 'Tissue', 'Risk_Category', 'First_Avail_TP', 'MYCN_Status', 'ALK_Status', 'TP53_Status', 'Response', 'Vital_Status', 'Age_at_IDX_in_months', 'Treatment', 'First_Avail_Time_Point', 'sample_name', 'biospecimen_id', 'percent.mt', 'seurat_clusters', 'sample_label_wo_prefix', 'S.Score', 'G2M.Score', 'Phase', 'malignancy', 'cell_state', 'RNA_snn_res.0.2', 'MES_Score', 'ADRN_Score', 'MES_ADRN_diff', 'Event', 'organism_ontology_term_id', 'donor_id', 'development_stage_ontology_term_id', 'sex_ontology_term_id', 'disease_ontology_term_id', 'tissue_type', 'cell_type_ontology_term_id', 'assay_ontology_term_id', 'suspension_type', 'tissue_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'is_primary_data', 'cell_type', 'assay', 'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid', 'cell_type_joint', 'SAMPLES_JOINT'
#     obsm: 'X_pca', 'X_scFoundation', 'X_umap', 'iPCA_scFoundation'

# %%
adata.write_h5ad(OUTPUT_DIR + 'nicolas_x_ipca.h5ad', compression='gzip')

# %% [markdown]
# ## Build 50‑nearest‑neighbor graph

# %%
sc.pp.neighbors(adata, use_rep=iPCA_KEY)

# %% [markdown]
# ## UMAP graph

# %% [markdown]
# ### SN(Train)_to_Endo(Test)_3000_Genes_CellState_X_scGPT

# %%
sc.tl.umap(adata)
umap_obs = ['SAMPLES_JOINT', 'CELL_TYPE_JOINT', 'cell_state', 'STAGE_CODE_JOINT']
for feature in umap_obs:
    sc.pl.umap(adata, color=feature, legend_fontsize=5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 sc.tl.umap(adata)
#       2 umap_obs = ['SAMPLES_JOINT', 'CELL_TYPE_JOINT', 'cell_state', 'STAGE_CODE_JOINT']
#       3 for feature in umap_obs:
#
# File /opt/anaconda3/envs/cancerGPT/lib/python3.10/site-packages/legacy_api_wrap/__init__.py:82, in legacy_api.<locals>.wrapper.<locals>.fn_compatible(*args_all, **kw)
#      79 @wraps(fn)
#      80 def fn_compatible(*args_all: P.args, **kw: P.kwargs) -> R:
#      81     if len(args_all) <= n_positional:
# ---> 82         return fn(*args_all, **kw)
#      84     args_pos: P.args
#      85     args_pos, args_rest = args_all[:n_positional], args_all[n_positional:]
#
# File /opt/anaconda3/envs/cancerGPT/lib/python3.10/site-packages/scanpy/tools/_umap.py:209, in umap(adata, min_dist, spread, n_components, maxiter, alpha, gamma, negative_sample_rate, init_pos, random_state, a, b, method, neighbors_key, copy)
#     207     default_epochs = 500 if neighbors["connectivities"].shape[0] <= 10000 else 200
#     208     n_epochs = default_epochs if maxiter is None else maxiter
# --> 209     X_umap, _ = simplicial_set_embedding(
#     210         data=X,
#     211         graph=neighbors["connectivities"].tocoo(),
#     212         n_components=n_components,
#     213         initial_alpha=alpha,
#     214         a=a,
#     215         b=b,
#     216         gamma=gamma,
#     217         negative_sample_rate=negative_sample_rate,
#     218         n_epochs=n_epochs,
#     219         init=init_coords,
#     220         random_state=random_state,
#     221         metric=neigh_params.get("metric", "euclidean"),
#     222         metric_kwds=neigh_params.get("metric_kwds", {}),
#     223         densmap=False,
#     224         densmap_kwds={},
#     225         output_dens=False,
#     226         verbose=settings.verbosity > 3,
#     227     )
#     228 elif method == "rapids":
#     229     msg = (
#     230         "`method='rapids'` is deprecated. "
#     231         "Use `rapids_singlecell.tl.louvain` instead."
#     232     )
#
# File /opt/anaconda3/envs/cancerGPT/lib/python3.10/site-packages/umap/umap_.py:1109, in simplicial_set_embedding(data, graph, n_components, initial_alpha, a, b, gamma, negative_sample_rate, n_epochs, init, random_state, metric, metric_kwds, densmap, densmap_kwds, output_dens, output_metric, output_metric_kwds, euclidean_output, parallel, verbose, tqdm_kwds)
#    1105     embedding = noisy_scale_coords(
#    1106         embedding, random_state, max_coord=10, noise=0.0001
#    1107     )
#    1108 elif isinstance(init, str) and init == "spectral":
# -> 1109     embedding = spectral_layout(
#    1110         data,
#    1111         graph,
#    1112         n_components,
#    1113         random_state,
#    1114         metric=metric,
#    1115         metric_kwds=metric_kwds,
#    1116     )
#    1117     # We add a little noise to avoid local minima for optimization to come
#    1118     embedding = noisy_scale_coords(
#    1119         embedding, random_state, max_coord=10, noise=0.0001
#    1120     )
#
# File /opt/anaconda3/envs/cancerGPT/lib/python3.10/site-packages/umap/spectral.py:304, in spectral_layout(data, graph, dim, random_state, metric, metric_kwds, tol, maxiter)
#     263 def spectral_layout(
#     264     data,
#     265     graph,
#    (...)
#     271     maxiter=0,
#     272 ):
#     273     """
#     274     Given a graph compute the spectral embedding of the graph. This is
#     275     simply the eigenvectors of the laplacian of the graph. Here we use the
#    (...)
#     302         The spectral embedding of the graph.
#     303     """
# --> 304     return _spectral_layout(
#     305         data=data,
#     306         graph=graph,
#     307         dim=dim,
#     308         random_state=random_state,
#     309         metric=metric,
#     310         metric_kwds=metric_kwds,
#     311         init="random",
#     312         tol=tol,
#     313         maxiter=maxiter,
#     314     )
#
# File /opt/anaconda3/envs/cancerGPT/lib/python3.10/site-packages/umap/spectral.py:519, in _spectral_layout(data, graph, dim, random_state, metric, metric_kwds, init, method, tol, maxiter)
#     516 X[:, 0] = sqrt_deg / np.linalg.norm(sqrt_deg)
#     518 if method == "eigsh":
# --> 519     eigenvalues, eigenvectors = scipy.sparse.linalg.eigsh(
#     520         L,
#     521         k,
#     522         which="SM",
#     523         ncv=num_lanczos_vectors,
#     524         tol=tol or 1e-4,
#     525         v0=np.ones(L.shape[0]),
#     526         maxiter=maxiter or graph.shape[0] * 5,
#     527     )
#     528 elif method == "lobpcg":
#     529     with warnings.catch_warnings():
#
# File /opt/anaconda3/envs/cancerGPT/lib/python3.10/site-packages/scipy/sparse/linalg/_eigen/arpack/arpack.py:1700, in eigsh(A, k, M, sigma, which, v0, ncv, maxiter, tol, return_eigenvectors, Minv, OPinv, mode)
#    1698 with _ARPACK_LOCK:
#    1699     while not params.converged:
# -> 1700         params.iterate()
#    1702     return params.extract(return_eigenvectors)
#
# File /opt/anaconda3/envs/cancerGPT/lib/python3.10/site-packages/scipy/sparse/linalg/_eigen/arpack/arpack.py:537, in _SymmetricArpackParams.iterate(self)
#     535 def iterate(self):
#     536     self.ido, self.tol, self.resid, self.v, self.iparam, self.ipntr, self.info = \
# --> 537         self._arpack_solver(self.ido, self.bmat, self.which, self.k,
#     538                             self.tol, self.resid, self.v, self.iparam,
#     539                             self.ipntr, self.workd, self.workl, self.info)
#     541     xslice = slice(self.ipntr[0] - 1, self.ipntr[0] - 1 + self.n)
#     542     yslice = slice(self.ipntr[1] - 1, self.ipntr[1] - 1 + self.n)
#
# KeyboardInterrupt:

# %% [markdown]
# ### SN(Train)_to_Combined(Test)_3000_Genes_CellState_X_scGPT

# %%
sc.tl.umap(adata)
umap_obs = ['SAMPLES_JOINT', 'CELL_TYPE_JOINT', 'cell_state', 'STAGE_CODE_JOINT']
for feature in umap_obs:
    sc.pl.umap(adata, color=feature, legend_fontsize=5)

# %% [markdown]
# ### SN(Train)_to_SN(Test)_3000HVG_CellState_X_scGPT

# %%
sc.tl.umap(adata)
umap_obs = ['donor_id', 'cell_type', 'cell_state', 'Stage_Code']
for feature in umap_obs:
    sc.pl.umap(adata, color=feature, legend_fontsize=5)
